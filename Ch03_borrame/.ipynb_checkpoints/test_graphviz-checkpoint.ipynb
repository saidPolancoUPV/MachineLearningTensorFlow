# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, TimeDistributed
import tensorflow.keras.models

# %%
mnist = tf.keras.datasets.mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step

# %%
inputs = tf.keras.Input(shape=(28, 28))
flatten_layer = keras.layers.Flatten()
flatten_output = flatten_layer(inputs)
dense_layer = tf.keras.layers.Dense(50, activation='relu')
dense_output = dense_layer(flatten_output)
predictions = Dense(10, activation='softmax')(dense_output)
model = keras.Model(inputs=inputs, outputs=predictions)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28)]          0
# _________________________________________________________________
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 50)                39250
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                510
# =================================================================
# Total params: 39,760
# Trainable params: 39,760
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='sgd',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 30.5680 - accuracy: 0.1619 - val_loss: 2.2002 - val_accuracy: 0.1460
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.1922 - accuracy: 0.1631 - val_loss: 2.3177 - val_accuracy: 0.1028
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.2254 - accuracy: 0.1484 - val_loss: 2.1951 - val_accuracy: 0.1473
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.2911 - accuracy: 0.1158 - val_loss: 2.1639 - val_accuracy: 0.1612
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.2301 - accuracy: 0.1413 - val_loss: 2.1551 - val_accuracy: 0.1648
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.1701 - accuracy: 0.1651 - val_loss: 2.1323 - val_accuracy: 0.1703
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.1790 - accuracy: 0.1602 - val_loss: 2.1688 - val_accuracy: 0.1571
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.1913 - accuracy: 0.1612 - val_loss: 2.1677 - val_accuracy: 0.1575
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.1585 - accuracy: 0.1669 - val_loss: 2.1417 - val_accuracy: 0.1666
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.1565 - accuracy: 0.1725 - val_loss: 2.1129 - val_accuracy: 0.1762

# %%
keras.utils.plot_model(model, 'funct_model_mnist.png', show_shapes=True)
